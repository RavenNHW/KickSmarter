# %%
from src.data_cleaning import *

# %reload_ext autoreload
# %autoreload 2
# import_functs()

# %% [markdown]
# With `import_ks_data()`, we will pull all of the raw kickstarter data from within the `data` folder, and combine it into one file. To avoid having to repeat this process, it automatically pickles the dataframe as `raw_ks_data.p`.

# %%
# df = import_ks_data()

# %% [markdown]
# If you're not running this notebook for the first time, then run `load_raw_ks_data` instead.

# %%
df = load_raw_ks_data()

# %%
df.head(3)
# Out:
#    backers_count                                              blurb  \
# 0              1  This is a project I created to find out why 10...
# 1             82  Seek & Behold is a full length album paired wi...
# 2             30  After a lifetime of talking myself out of shar...
#
#                                             category  \
# 0  {"id":360,"name":"Video","slug":"journalism/vi...
# 1  {"id":318,"name":"Faith","slug":"music/faith",...
# 2  {"id":318,"name":"Faith","slug":"music/faith",...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                        20      US        the United States  1494022111
# 1                     12580      US        the United States  1477503356
# 2                      2491      US        the United States  1426640212
#
#                                              creator currency currency_symbol  \
# 0  {"id":220745515,"name":"Stephanie Balfrey","sl...      USD               $
# 1  {"id":1889961770,"name":"Debrianna Grace Cabit...      USD               $
# 2  {"id":1600855781,"name":"Liz Roberson","is_reg...      USD               $
#
#    ...  spotlight staff_pick       state  state_changed_at static_usd_rate  \
# 0  ...      False      False      failed        1499212951             1.0
# 1  ...       True      False  successful        1482825631             1.0
# 2  ...       True      False  successful        1429238223             1.0
#
#    unread_messages_count  unseen_activity_count  \
# 0                    NaN                    NaN
# 1                    NaN                    NaN
# 2                    NaN                    NaN
#
#                                                 urls usd_pledged  usd_type
# 0  {"web":{"project":"https://www.kickstarter.com...        20.0  domestic
# 1  {"web":{"project":"https://www.kickstarter.com...     12580.0  domestic
# 2  {"web":{"project":"https://www.kickstarter.com...      2491.0  domestic
#
# [3 rows x 41 columns]

# %% [markdown]
# Some immidiately noticable things include the category column, which conains dictionaries. With a closer look...

# %%
df.category[0]
# Out:
# '{"id":360,"name":"Video","slug":"journalism/video","position":4,"parent_id":13,"parent_name":"Journalism","color":1228010,"urls":{"web":{"discover":"http://www.kickstarter.com/discover/categories/journalism/video"}}}'

# %% [markdown]
# We can see that it contains important information, such as the category name and the parent category, if the project is within a subcategory. However most of the information isn't useful, so using `expand_cateogry` we expand that column, and extract just the `name` and `parent_name` columns, renaming them to `category_name` and `category_parent_name`

# %%
df = expand_category(df)
df.head(3)
# Out:
#    backers_count                                              blurb  \
# 0              1  This is a project I created to find out why 10...
# 1             82  Seek & Behold is a full length album paired wi...
# 2             30  After a lifetime of talking myself out of shar...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                        20      US        the United States  1494022111
# 1                     12580      US        the United States  1477503356
# 2                      2491      US        the United States  1426640212
#
#                                              creator currency currency_symbol  \
# 0  {"id":220745515,"name":"Stephanie Balfrey","sl...      USD               $
# 1  {"id":1889961770,"name":"Debrianna Grace Cabit...      USD               $
# 2  {"id":1600855781,"name":"Liz Roberson","is_reg...      USD               $
#
#    currency_trailing_code  ...       state  state_changed_at  static_usd_rate  \
# 0                    True  ...      failed        1499212951              1.0
# 1                    True  ...  successful        1482825631              1.0
# 2                    True  ...  successful        1429238223              1.0
#
#   unread_messages_count  unseen_activity_count  \
# 0                   NaN                    NaN
# 1                   NaN                    NaN
# 2                   NaN                    NaN
#
#                                                 urls  usd_pledged  usd_type  \
# 0  {"web":{"project":"https://www.kickstarter.com...         20.0  domestic
# 1  {"web":{"project":"https://www.kickstarter.com...      12580.0  domestic
# 2  {"web":{"project":"https://www.kickstarter.com...       2491.0  domestic
#
#    category_name category_parent_name
# 0          Video           Journalism
# 1          Faith                Music
# 2          Faith                Music
#
# [3 rows x 42 columns]

# %%
df.category_parent_name.fillna(value = df.category_name, inplace = True)

# %%
df[['category_name','category_parent_name']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195334 entries, 0 to 195333
# Data columns (total 2 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   category_name         195334 non-null  object
#  1   category_parent_name  195334 non-null  object
# dtypes: object(2)
# memory usage: 3.0+ MB

# %%
df
# Out:
#         backers_count                                              blurb  \
# 0                   1  This is a project I created to find out why 10...
# 1                  82  Seek & Behold is a full length album paired wi...
# 2                  30  After a lifetime of talking myself out of shar...
# 3                 109  The St.Claire is a critical and creative force...
# 4                  68  Trasformiamo un Bar in un Gamers' Café!!\nBirr...
# ...               ...                                                ...
# 195329             15  The Transporter is a floating island of light ...
# 195330            287  The culmination of years of research from diff...
# 195331             20  New album from Simon Scardanelli - narrative s...
# 195332              0  Lovely & Derby needs to raise funds to get som...
# 195333              9  Nut Delights and more- Gluten free,soy free,re...
#
#         converted_pledged_amount country country_displayable_name  created_at  \
# 0                             20      US        the United States  1494022111
# 1                          12580      US        the United States  1477503356
# 2                           2491      US        the United States  1426640212
# 3                           8300      US        the United States  1368571088
# 4                           7873      IT                    Italy  1479044849
# ...                          ...     ...                      ...         ...
# 195329                      2202      US        the United States  1394258709
# 195330                     11289      US        the United States  1431807042
# 195331                       983      GB       the United Kingdom  1448364875
# 195332                         0      US        the United States  1286032151
# 195333                       218      US        the United States  1421632434
#
#                                                   creator currency  \
# 0       {"id":220745515,"name":"Stephanie Balfrey","sl...      USD
# 1       {"id":1889961770,"name":"Debrianna Grace Cabit...      USD
# 2       {"id":1600855781,"name":"Liz Roberson","is_reg...      USD
# 3       {"id":884672734,"name":"THE ST.CLAIRE","is_reg...      USD
# 4       {"id":1385445347,"name":"Emanuele Iannone","is...      EUR
# ...                                                   ...      ...
# 195329  {"id":1850262460,"name":"Abram Santa Cruz","sl...      USD
# 195330  {"id":448215363,"name":"ZED Presents...","slug...      USD
# 195331  {"id":212545136,"name":"Simon Scardanelli","sl...      GBP
# 195332  {"id":499367211,"name":"Janice Priest","is_reg...      USD
# 195333  {"id":1654829927,"name":"MJ","slug":"mjduhvega...      USD
#
#        currency_symbol  currency_trailing_code  ...       state  \
# 0                    $                    True  ...      failed
# 1                    $                    True  ...  successful
# 2                    $                    True  ...  successful
# 3                    $                    True  ...  successful
# 4                    €                   False  ...  successful
# ...                ...                     ...  ...         ...
# 195329               $                    True  ...  successful
# 195330               $                    True  ...  successful
# 195331               £                   False  ...  successful
# 195332               $                    True  ...      failed
# 195333               $                    True  ...      failed
#
#         state_changed_at  static_usd_rate unread_messages_count  \
# 0             1499212951         1.000000                   NaN
# 1             1482825631         1.000000                   NaN
# 2             1429238223         1.000000                   NaN
# 3             1372813821         1.000000                   NaN
# 4             1483829940         1.058929                   NaN
# ...                  ...              ...                   ...
# 195329        1395723901         1.000000                   NaN
# 195330        1435733944         1.000000                   NaN
# 195331        1450976401         1.513441                   NaN
# 195332        1326316165         1.000000                   NaN
# 195333        1426987503         1.000000                   NaN
#
#         unseen_activity_count  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 195329                    NaN
# 195330                    NaN
# 195331                    NaN
# 195332                    NaN
# 195333                    NaN
#
#                                                      urls   usd_pledged  \
# 0       {"web":{"project":"https://www.kickstarter.com...     20.000000
# 1       {"web":{"project":"https://www.kickstarter.com...  12580.000000
# 2       {"web":{"project":"https://www.kickstarter.com...   2491.000000
# 3       {"web":{"project":"https://www.kickstarter.com...   8300.000000
# 4       {"web":{"project":"https://www.kickstarter.com...   7914.438485
# ...                                                   ...           ...
# 195329  {"web":{"project":"https://www.kickstarter.com...   2202.000000
# 195330  {"web":{"project":"https://www.kickstarter.com...  11289.000000
# 195331  {"web":{"project":"https://www.kickstarter.com...   1000.384415
# 195332  {"web":{"project":"https://www.kickstarter.com...      0.000000
# 195333  {"web":{"project":"https://www.kickstarter.com...    218.000000
#
#         usd_type    category_name category_parent_name
# 0       domestic            Video           Journalism
# 1       domestic            Faith                Music
# 2       domestic            Faith                Music
# 3       domestic       Journalism           Journalism
# 4       domestic      Restaurants                 Food
# ...          ...              ...                  ...
# 195329  domestic       Public Art                  Art
# 195330  domestic        Art Books           Publishing
# 195331  domestic   Country & Folk                Music
# 195332  domestic  Performance Art                  Art
# 195333  domestic            Vegan                 Food
#
# [195334 rows x 42 columns]

# %% [markdown]
# Next, we're going to begin correcting data types.
#
# All dates are in unix format, so the following four columns will be changed to datetime64[s]
#     - `created_at`, `deadline`, `launched_at`, `state_changed`
#
# On top of that, we'll be correcting the datatypes for a few more columns!
# - `country`, `currency`, `currency_symbol`, `category_name`, and `category_parent_name` will be changed to the pandas datatype `category`
#
# - `state` will be updated to change `successful` into 1, and `failed` into 0

# %%
df = correct_dtypes(df)
df = drop_rows(df)
df = drop_cols(df)
# Out:
# C:\Users\Raven (Work)\Desktop\Flatiron\Final_Proj\Kickstarter\src\data_cleaning.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inplace = True)

# %%
df['start_month'] = pd.DatetimeIndex(df['launched_at']).month
df['end_month'] = pd.DatetimeIndex(df['deadline']).month

# %%
blurb_df, df = split_and_pickle_df(df)

# %%
dict_list, df = create_dicts(df)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(df, test_size = .2, random_state = seed)

# %%
col_list = ['category_parent_name', 'currency', 'country']

encoded_train_df = df_train
encoded_test_df = df_test
le = LabelEncoder()
LE_dict = {}

for i in col_list:
    le.fit(encoded_train_df[i])
    encoded_train_df[i] = le.transform(encoded_train_df[i])
    encoded_test_df[i] = le.transform(encoded_test_df[i])
    LE_dict[i] = le.classes_

LE_dict
# Out:
# C:\Users\Raven (Work)\.conda\envs\ks_env\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Raven (Work)\.conda\envs\ks_env\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# {'category_parent_name': array(['Art', 'Comics', 'Crafts', 'Dance', 'Design', 'Fashion',
#         'Film & Video', 'Food', 'Games', 'Journalism', 'Music',
#         'Photography', 'Publishing', 'Technology', 'Theater'], dtype=object),
#  'currency': array(['AUD', 'CAD', 'CHF', 'DKK', 'EUR', 'GBP', 'HKD', 'JPY', 'MXN',
#         'NOK', 'NZD', 'SEK', 'SGD', 'USD'], dtype=object),
#  'country': array(['AT', 'AU', 'BE', 'CA', 'CH', 'DE', 'DK', 'ES', 'FR', 'GB', 'HK',
#         'IE', 'IT', 'JP', 'LU', 'MX', 'NL', 'NO', 'NZ', 'SE', 'SG', 'US'],
#        dtype=object)}

# %%
encoded_train_df.to_pickle('data/KS_train_data.pkl')
encoded_test_df.to_pickle('data/KS_test_data.pkl')

# %%
dates = ['deadline', 'launched_at']

def expand_date(df, col):
    times = ['year', 'month', 'day']
    
    col_name = f"{col}_year"
    df[col_name] = df[col].year
    
    col_name = f"{col}_month"
    df[col_name] = df[col].month
    
    col_name = f"{col}_day"
    df[col_name] = df[col].day
    
    return df.drop(columns = col)

# %%
expand_date(df, 'deadline')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-2753188662d8> in <module>
# ----> 1 expand_date(df, 'deadline')
#
# <ipython-input-18-9594bc20f616> in expand_date(df, col)
#       5
#       6     col_name = f"{col}_year"
# ----> 7     df[col_name] = df[col].year
#       8
#       9     col_name = f"{col}_month"
#
# ~\.conda\envs\ks_env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'year'
