# %%
from src.data_cleaning import *

# %reload_ext autoreload
# %autoreload 2
# import_functs()

# %% [markdown]
# With `import_ks_data()`, we will pull all of the raw kickstarter data from within the `data` folder, and combine it into one file. To avoid having to repeat this process, it automatically pickles the dataframe as `raw_ks_data.p`.
#
# **Important!** Before running this, please make sure to download the data [here](https://drive.google.com/file/d/1R95VR0kpbABkCy8f_CO5pJPikeaudo2H/view?usp=sharing) and save it in `data` as `Kickstarter_CSVs.zip`, and unzip the file.

# %%
## Uncomment to run
# df = import_ks_data()

# %% [markdown]
# If you're not running this notebook for the first time, then run `load_raw_ks_data` instead.

# %%
df = load_raw_ks_data()

# %%
df.head(3)
# Out:
#    backers_count                                              blurb  \
# 0              1  This is a project I created to find out why 10...
# 1             82  Seek & Behold is a full length album paired wi...
# 2             30  After a lifetime of talking myself out of shar...
#
#                                             category  \
# 0  {"id":360,"name":"Video","slug":"journalism/vi...
# 1  {"id":318,"name":"Faith","slug":"music/faith",...
# 2  {"id":318,"name":"Faith","slug":"music/faith",...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                        20      US        the United States  1494022111
# 1                     12580      US        the United States  1477503356
# 2                      2491      US        the United States  1426640212
#
#                                              creator currency currency_symbol  \
# 0  {"id":220745515,"name":"Stephanie Balfrey","sl...      USD               $
# 1  {"id":1889961770,"name":"Debrianna Grace Cabit...      USD               $
# 2  {"id":1600855781,"name":"Liz Roberson","is_reg...      USD               $
#
#    currency_trailing_code current_currency    deadline  disable_communication  \
# 0                    True              USD  1499212951                  False
# 1                    True              USD  1482825631                  False
# 2                    True              USD  1429238219                  False
#
#   friends  fx_rate     goal          id is_backing  is_starrable is_starred  \
# 0     NaN      1.0   1000.0   104592348        NaN         False        NaN
# 1     NaN      1.0  10000.0  1852641962        NaN         False        NaN
# 2     NaN      1.0   2000.0    64426037        NaN         False        NaN
#
#    last_update_published_at  launched_at  \
# 0                       NaN   1494028951
# 1                       NaN   1478505631
# 2                       NaN   1426646219
#
#                                             location  \
# 0  {"id":2503863,"name":"Tampa","slug":"tampa-fl"...
# 1  {"id":2385447,"name":"Costa Mesa","slug":"cost...
# 2  {"id":2430835,"name":"Katy","slug":"katy-tx","...
#
#                                      name permissions  \
# 0        Breast Cancer Mission Impossible         NaN
# 1  Debrianna Grace Cabitac: Seek & Behold         NaN
# 2               Liz Roberson Debut Album!         NaN
#
#                                                photo  pledged  \
# 0  {"key":"assets/016/550/794/0f20795a1f7d1219d64...     20.0
# 1  {"key":"assets/014/355/790/607842fe5163267e666...  12580.0
# 2  {"key":"assets/012/072/616/3942c9eeecd39a1cd87...   2491.0
#
#                                              profile  \
# 0  {"id":2989151,"project_id":2989151,"state":"in...
# 1  {"id":2734869,"project_id":2734869,"state":"in...
# 2  {"id":1776308,"project_id":1776308,"state":"ac...
#
#                                       slug  \
# 0         breast-cancer-mission-impossible
# 1  debrianna-grace-cabitac-seek-and-behold
# 2                 liz-roberson-debut-album
#
#                                           source_url  spotlight  staff_pick  \
# 0  https://www.kickstarter.com/discover/categorie...      False       False
# 1  https://www.kickstarter.com/discover/categorie...       True       False
# 2  https://www.kickstarter.com/discover/categorie...       True       False
#
#         state  state_changed_at  static_usd_rate  unread_messages_count  \
# 0      failed        1499212951              1.0                    NaN
# 1  successful        1482825631              1.0                    NaN
# 2  successful        1429238223              1.0                    NaN
#
#    unseen_activity_count                                               urls  \
# 0                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 1                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 2                    NaN  {"web":{"project":"https://www.kickstarter.com...
#
#    usd_pledged  usd_type
# 0         20.0  domestic
# 1      12580.0  domestic
# 2       2491.0  domestic

# %% [markdown]
# Some immidiately noticable things include the category column, which conains dictionaries. With a closer look...

# %%
df.category.iloc[0]
# Out:
# '{"id":360,"name":"Video","slug":"journalism/video","position":4,"parent_id":13,"parent_name":"Journalism","color":1228010,"urls":{"web":{"discover":"http://www.kickstarter.com/discover/categories/journalism/video"}}}'

# %% [markdown]
# We can see that it contains important information, such as the category name and the parent category, if the project is within a subcategory. However most of the information isn't useful, so using `expand_cateogry` we expand that column, and extract just the `name` and `parent_name` columns, renaming them to `category_name` and `category_parent_name`.
# Since we just want the main category, not the sub-category, all of the blanks in `category_parent_name` will be replaced with the items in `category_name`

# %%
df = expand_category(df)
df.head(3)
# Out:
#    backers_count                                              blurb  \
# 0              1  This is a project I created to find out why 10...
# 1             82  Seek & Behold is a full length album paired wi...
# 2             30  After a lifetime of talking myself out of shar...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                        20      US        the United States  1494022111
# 1                     12580      US        the United States  1477503356
# 2                      2491      US        the United States  1426640212
#
#                                              creator currency currency_symbol  \
# 0  {"id":220745515,"name":"Stephanie Balfrey","sl...      USD               $
# 1  {"id":1889961770,"name":"Debrianna Grace Cabit...      USD               $
# 2  {"id":1600855781,"name":"Liz Roberson","is_reg...      USD               $
#
#    currency_trailing_code current_currency    deadline  disable_communication  \
# 0                    True              USD  1499212951                  False
# 1                    True              USD  1482825631                  False
# 2                    True              USD  1429238219                  False
#
#   friends  fx_rate     goal          id is_backing  is_starrable is_starred  \
# 0     NaN      1.0   1000.0   104592348        NaN         False        NaN
# 1     NaN      1.0  10000.0  1852641962        NaN         False        NaN
# 2     NaN      1.0   2000.0    64426037        NaN         False        NaN
#
#    last_update_published_at  launched_at  \
# 0                       NaN   1494028951
# 1                       NaN   1478505631
# 2                       NaN   1426646219
#
#                                             location  \
# 0  {"id":2503863,"name":"Tampa","slug":"tampa-fl"...
# 1  {"id":2385447,"name":"Costa Mesa","slug":"cost...
# 2  {"id":2430835,"name":"Katy","slug":"katy-tx","...
#
#                                      name permissions  \
# 0        Breast Cancer Mission Impossible         NaN
# 1  Debrianna Grace Cabitac: Seek & Behold         NaN
# 2               Liz Roberson Debut Album!         NaN
#
#                                                photo  pledged  \
# 0  {"key":"assets/016/550/794/0f20795a1f7d1219d64...     20.0
# 1  {"key":"assets/014/355/790/607842fe5163267e666...  12580.0
# 2  {"key":"assets/012/072/616/3942c9eeecd39a1cd87...   2491.0
#
#                                              profile  \
# 0  {"id":2989151,"project_id":2989151,"state":"in...
# 1  {"id":2734869,"project_id":2734869,"state":"in...
# 2  {"id":1776308,"project_id":1776308,"state":"ac...
#
#                                       slug  \
# 0         breast-cancer-mission-impossible
# 1  debrianna-grace-cabitac-seek-and-behold
# 2                 liz-roberson-debut-album
#
#                                           source_url  spotlight  staff_pick  \
# 0  https://www.kickstarter.com/discover/categorie...      False       False
# 1  https://www.kickstarter.com/discover/categorie...       True       False
# 2  https://www.kickstarter.com/discover/categorie...       True       False
#
#         state  state_changed_at  static_usd_rate  unread_messages_count  \
# 0      failed        1499212951              1.0                    NaN
# 1  successful        1482825631              1.0                    NaN
# 2  successful        1429238223              1.0                    NaN
#
#    unseen_activity_count                                               urls  \
# 0                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 1                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 2                    NaN  {"web":{"project":"https://www.kickstarter.com...
#
#    usd_pledged  usd_type category_parent_name
# 0         20.0  domestic           Journalism
# 1      12580.0  domestic                Music
# 2       2491.0  domestic                Music

# %% [markdown]
# Next, we're going to begin correcting data types.
#
# All dates are in unix format, so the following four columns will be changed to datetime64[s]
#     - `created_at`, `deadline`, `launched_at`, `state_changed`
#
# On top of that, we'll be correcting the datatypes for a few more columns!
# - `country`, `currency`, `currency_symbol`, and `category_parent_name` will be changed to the pandas datatype `category`
#
# - `state` will be updated to change `successful` into 1, and `failed` into 0
#
# As well as dropping unwanted columns, and duplicate rows!

# %%
df = correct_dtypes(df)
df = drop_rows(df)
df = drop_cols(df)

# %% [markdown]
# Next, we'll be extracting the end and start dates for each project, as well as the project length!
# On top of that, we will also be dropping the original date columns.

# %%
df = extract_dates(df)

# %% [markdown]
# With that, we'll also split and pickle the DataFrames as `KS_data.pkl` and `KS_blurb_data.pkl`, removing the blurb text and adding the length of the blurbs to the dataframe.
#
#    - `KS_data.pkl` will be used for visualizations
#    - `KS_blurb_data.pkl` sets aside the blurb text for future NLP use

# %%
blurb_df, df = split_and_pickle_df(df)

# %%
df.head()
# Out:
#        country country_displayable_name currency currency_symbol     goal  \
# 122550      US        the United States      USD               $   3600.0
# 64587       US        the United States      USD               $   1500.0
# 91387       GB       the United Kingdom      GBP               £     25.0
# 76726       US        the United States      USD               $  37500.0
# 161875      US        the United States      USD               $    500.0
#
#                 id  staff_pick  state category_parent_name  start_month  \
# 122550  1134843983       False      0                Games            5
# 64587   1094489060       False      1                Games            5
# 91387   2051827639       False      1                Games            6
# 76726   1188113847        True      1               Comics            5
# 161875   299455523       False      1                Games            5
#
#         end_month  project_length  blurb_len
# 122550          6              26         76
# 64587           6              22         70
# 91387           6               5        133
# 76726           6              28        132
# 161875          6              21         41

# %% [markdown]
# Next, we'll be taking the `currency_symbol` and `country_displayable_name` columns and storing them in a dictionary, using `country` and `currency` as keys. This is for vizualization use, as well as removing redundant columns
#
# `state` will also be switched to numbers, a 1 for successful projects and a 0 for failed.

# %%
dict_list, df = create_dicts(df)

# %% [markdown]
# After that, it's on to label encoding string columns so that they can be fed into different machine learning algorithms. We're using SKLearn's label encoder, and outputting it to `LE_dict` for decoding use in case we need it.

# %%
enc_train_df, enc_test_df, LE_dict = split_and_encode(df)

# %%
enc_train_df.head()
# Out:
#             country  currency     goal  staff_pick  state  \
# id
# 864202524        21        13   6200.0        True      1
# 1329733276        8         4  20000.0       False      1
# 1123973612       21        13  40000.0        True      1
# 1226762918       21        13  15000.0       False      0
# 132864990         1         0  25000.0        True      1
#
#             category_parent_name  start_month  end_month  project_length  \
# id
# 864202524                      2            6          7              30
# 1329733276                    13            9          9              22
# 1123973612                     8            4          5              30
# 1226762918                     0            2          3              29
# 132864990                      6            4          5              26
#
#             blurb_len
# id
# 864202524         100
# 1329733276         46
# 1123973612        132
# 1226762918        134
# 132864990         129

# %% [markdown]
# And that's it! Both the train and test data are pickled, as well as the label encoder and dictionary, all ready to be used in other ways.

# %%
enc_train_df.to_pickle('data/KS_train_data.pkl')
enc_test_df.to_pickle('data/KS_test_data.pkl')

pickle.dump([dict_list, LE_dict], open('data/encoders.pkl', 'wb'))
